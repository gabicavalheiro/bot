# %%
import pyautogui
import time

def find_color_in_region(target_color, region):
    screenshot = pyautogui.screenshot(region=(region[0], region[1], region[2] - region[0], region[3] - region[1]))
    width, height = screenshot.size

    for x in range(width):
        for y in range(height):
            pixel_color = screenshot.getpixel((x, y))
            if pixel_color == target_color:
                return x + region[0], y + region[1]

    return None

def calculate_color_proximity(color1, color2):
    proximity = sum(abs(c1 - c2) for c1, c2 in zip(color1, color2))
    return proximity / 3 #divide entre as 3 cores do rgb  


target_color = (227, 227, 218)
target_color2 = (232, 190, 87)
region_to_search = (479, 162, 591, 881)  # (left, top, right, bottom)

pyautogui.PAUSE = 1
proximity_threshold = 46.4

while True:
    pixel_coordinates = find_color_in_region(target_color, region_to_search)
    pixel_coordinates2 = find_color_in_region(target_color2, region_to_search)

    if pixel_coordinates and pixel_coordinates2:
        print(f"A cor foi encontrada nas coordenadas: {pixel_coordinates}")
        print(f"A cor 2 foi encontrada nas coordenadas: {pixel_coordinates2}")

        proximity_value = calculate_color_proximity(pixel_coordinates, pixel_coordinates2)
        print(f"Grau de proximidade entre as coordenadas: {proximity_value}")

        if proximity_value <= proximity_threshold:
            print("Coordenadas próximas! Clicando...")
            pyautogui.click(pixel_coordinates2[0], pixel_coordinates2[1])
        else:
            print("Coordenadas não estão próximas o suficiente.")
    else:
        print("A cor não foi encontrada na região especificada.")
# Out:
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (481, 183)
# A cor 2 foi encontrada nas coordenadas: (483, 552)
# Grau de proximidade entre as coordenadas: 123.66666666666667
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 222)
# A cor 2 foi encontrada nas coordenadas: (482, 552)
# Grau de proximidade entre as coordenadas: 110.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (490, 225)
# A cor 2 foi encontrada nas coordenadas: (482, 553)
# Grau de proximidade entre as coordenadas: 112.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 325)
# A cor 2 foi encontrada nas coordenadas: (482, 551)
# Grau de proximidade entre as coordenadas: 75.66666666666667
# Coordenadas não estão próximas o suficiente.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (481, 447)
# A cor 2 foi encontrada nas coordenadas: (482, 551)
# Grau de proximidade entre as coordenadas: 35.0
# Coordenadas próximas! Clicando...
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (554, 427)
# A cor 2 foi encontrada nas coordenadas: (479, 530)
# Grau de proximidade entre as coordenadas: 59.333333333333336
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (511, 484)
# A cor 2 foi encontrada nas coordenadas: (479, 530)
# Grau de proximidade entre as coordenadas: 26.0
# Coordenadas próximas! Clicando...
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (529, 488)
# A cor 2 foi encontrada nas coordenadas: (479, 531)
# Grau de proximidade entre as coordenadas: 31.0
# Coordenadas próximas! Clicando...
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (571, 346)
# A cor 2 foi encontrada nas coordenadas: (479, 532)
# Grau de proximidade entre as coordenadas: 92.66666666666667
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (517, 423)
# A cor 2 foi encontrada nas coordenadas: (479, 533)
# Grau de proximidade entre as coordenadas: 49.333333333333336
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (539, 440)
# A cor 2 foi encontrada nas coordenadas: (479, 533)
# Grau de proximidade entre as coordenadas: 51.0
# Coordenadas não estão próximas o suficiente.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (487, 613)
# A cor 2 foi encontrada nas coordenadas: (479, 532)
# Grau de proximidade entre as coordenadas: 29.666666666666668
# Coordenadas próximas! Clicando...
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (481, 188)
# A cor 2 foi encontrada nas coordenadas: (483, 550)
# Grau de proximidade entre as coordenadas: 121.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (496, 209)
# A cor 2 foi encontrada nas coordenadas: (482, 553)
# Grau de proximidade entre as coordenadas: 119.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 295)
# A cor 2 foi encontrada nas coordenadas: (482, 553)
# Grau de proximidade entre as coordenadas: 86.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 334)
# A cor 2 foi encontrada nas coordenadas: (482, 552)
# Grau de proximidade entre as coordenadas: 73.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 374)
# A cor 2 foi encontrada nas coordenadas: (482, 551)
# Grau de proximidade entre as coordenadas: 59.333333333333336
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 432)
# A cor 2 foi encontrada nas coordenadas: (482, 552)
# Grau de proximidade entre as coordenadas: 40.333333333333336
# Coordenadas próximas! Clicando...
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (546, 221)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 131.33333333333334
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (553, 338)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 94.66666666666667
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (519, 387)
# A cor 2 foi encontrada nas coordenadas: (480, 546)
# Grau de proximidade entre as coordenadas: 66.0
# Coordenadas não estão próximas o suficiente.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (557, 482)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 48.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (493, 603)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 23.0
# Coordenadas próximas! Clicando...
# A cor foi encontrada nas coordenadas: (540, 253)
# A cor 2 foi encontrada nas coordenadas: (480, 547)
# Grau de proximidade entre as coordenadas: 118.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (532, 288)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 104.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (549, 373)
# A cor 2 foi encontrada nas coordenadas: (479, 549)
# Grau de proximidade entre as coordenadas: 82.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (514, 404)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 59.666666666666664
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (498, 479)
# A cor 2 foi encontrada nas coordenadas: (479, 548)
# Grau de proximidade entre as coordenadas: 29.333333333333332
# Coordenadas próximas! Clicando...
# A cor foi encontrada nas coordenadas: (543, 232)
# A cor 2 foi encontrada nas coordenadas: (479, 547)
# Grau de proximidade entre as coordenadas: 126.33333333333333
# Coordenadas não estão próximas o suficiente.
# A cor não foi encontrada na região especificada.
# A cor foi encontrada nas coordenadas: (483, 700)
# A cor 2 foi encontrada nas coordenadas: (479, 539)
# Grau de proximidade entre as coordenadas: 55.0
# Coordenadas não estão próximas o suficiente.
# A cor foi encontrada nas coordenadas: (481, 638)
# A cor 2 foi encontrada nas coordenadas: (479, 529)
# Grau de proximidade entre as coordenadas: 37.0
# Coordenadas próximas! Clicando...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Gabi\Desktop\4 semestre\ia\tarefa- bot\tapdash\pyautoguitest.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a>     pixel_coordinates = find_color_in_region(target_color, region_to_search)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a>     pixel_coordinates2 = find_color_in_region(target_color2, region_to_search)
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     if pixel_coordinates and pixel_coordinates2:
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>         print(f"A cor foi encontrada nas coordenadas: {pixel_coordinates}")
#
# c:\Users\Gabi\Desktop\4 semestre\ia\tarefa- bot\tapdash\pyautoguitest.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> for x in range(width):
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>     for y in range(height):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>         pixel_color = screenshot.getpixel((x, y))
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>         if pixel_color == target_color:
#      <a href='vscode-notebook-cell:/c%3A/Users/Gabi/Desktop/4%20semestre/ia/tarefa-%20bot/tapdash/pyautoguitest.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>             return x + region[0], y + region[1]
#
# File c:\Python312\Lib\site-packages\PIL\Image.py:1577, in Image.getpixel(self, xy)
#    1573     self.palette.dirty = 1
#    1575     del self.info["transparency"]
# -> 1577 def getpixel(self, xy):
#    1578     """
#    1579     Returns the pixel value at a given position.
#    1580
#    (...)
#    1584        this method returns a tuple.
#    1585     """
#    1587     self.load()
#
# KeyboardInterrupt:
